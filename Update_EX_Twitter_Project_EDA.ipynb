# %%
#Import Libraries
# !pip install wordcloud
# !pip install plotly
from collections import Counter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import nltk
from nltk.corpus import stopwords
import string
import re
from textblob import TextBlob
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('stopwords')
nltk.download('vader_lexicon')

# !pip install unidecode
import unidecode
import plotly.io as pio
import plotly.plotly as py
from plotly.offline import init_notebook_mode, iplot
pyo.init_notebook_mode()
import warnings 
warnings.filterwarnings("ignore")
# Out:
# Requirement already satisfied: wordcloud in /Users/kylielee/opt/anaconda3/lib/python3.8/site-packages (1.8.1)
# Requirement already satisfied: matplotlib in /Users/kylielee/opt/anaconda3/lib/python3.8/site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: pillow in /Users/kylielee/opt/anaconda3/lib/python3.8/site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: numpy>=1.6.1 in /Users/kylielee/opt/anaconda3/lib/python3.8/site-packages (from wordcloud) (1.21.2)
# Requirement already satisfied: cycler>=0.10 in /Users/kylielee/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/kylielee/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kylielee/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/kylielee/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: six in /Users/kylielee/opt/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: plotly in /Users/kylielee/opt/anaconda3/lib/python3.8/site-packages (5.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/kylielee/opt/anaconda3/lib/python3.8/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /Users/kylielee/opt/anaconda3/lib/python3.8/site-packages (from plotly) (1.16.0)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kylielee/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/kylielee/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Requirement already satisfied: unidecode in /Users/kylielee/opt/anaconda3/lib/python3.8/site-packages (1.3.2)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/6n/q94yftms6xzc26x8ghsjc9h40000gn/T/ipykernel_88613/4005742428.py in <module>
#      26 import unidecode
#      27 import plotly.io as pio
# ---> 28 import plotly.plotly as py
#      29 from plotly.offline import init_notebook_mode, iplot
#      30 pyo.init_notebook_mode()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/plotly/__init__.py in <module>
#       2 from _plotly_future_ import _chart_studio_error
#       3
# ----> 4 _chart_studio_error("plotly")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/_plotly_future_/__init__.py in _chart_studio_error(submodule)
#      41
#      42 def _chart_studio_error(submodule):
# ---> 43     raise ImportError(
#      44         """
#      45 The plotly.{submodule} module is deprecated,
#
# ImportError:
# The plotly.plotly module is deprecated,
# please install the chart-studio package and use the
# chart_studio.plotly module instead.

# %%
from nltk.stem import WordNetLemmatizer 
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer
nltk.download('punkt')
from nltk.tokenize import word_tokenize 
import matplotlib.animation as animation
import operator
from collections import Counter

def dfCleaning(df):

    #import pandas_profiling

    #df = df[['text','retweet_count','favorite_count']]
    df.drop_duplicates(inplace = True)
    #Lowercase
    df['clean_tweet']= df['text'].apply(lambda x : x.lower())
    #Code to remove https
    df['clean_tweet'] = df['clean_tweet'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])
    #Code to remove @
    df['clean_tweet'] = df['clean_tweet'].apply(
        lambda x : ' '.join([tweet for tweet in x.split()if not tweet.startswith("@")]))
    #Removing numbers
    df['clean_tweet'] = df['clean_tweet'].apply(
        lambda x : ' '.join([tweet for tweet in x.split() if not tweet == '\d*']))
    #Removing all the greek characters using unidecode library
    df['clean_tweet'] = df['clean_tweet'].apply(
        lambda x : ' '.join([unidecode.unidecode(word) for word in x.split()])) 
    #Removing the word 'hmm' and it's variants
    df['clean_tweet'] = df['clean_tweet'].apply(
        lambda x : ' '.join([word for word in x.split() if not word == 'h(m)+' ]))
    #Code for removing slang words
    d = {'luv':'love','wud':'would','lyk':'like','wateva':'whatever','ttyl':'talk to you later',
                   'kul':'cool','fyn':'fine','omg':'oh my god!','fam':'family','bruh':'brother',
                   'cud':'could','fud':'food','gal':'girl'} ## Need a huge dictionary
    words = "I luv myself"
    words = words.split()
    reformed = [d[word] if word in d else word for word in words]
    reformed = " ".join(reformed)
    
    df['clean_tweet'] = df['clean_tweet'].apply(
        lambda x : ' '.join(d[word] if word in d else word for word in x.split()))
    
    #Finding words with # attached to it
    df['#'] = df['clean_tweet'].apply(
        lambda x : ' '.join([word for word in x.split() if word.startswith('#')]))
    frame = df['#']
    frame = pd.DataFrame(frame)
    frame = frame.rename({'#':'Count(#)'},axis = 'columns')
    frame[frame['Count(#)'] == ''] = 'No hashtags'
    data_frame = pd.concat([df,frame],axis = 1)
    data_frame.drop('#',axis = 1,inplace = True)
    
    #Column showing whether the corresponding tweet has a hash tagged word or not
    data_frame = data_frame.rename({'Count(#)':'Hash words'},axis = 'columns')

    #Removing stopwords
    data_frame['clean_tweet'] = data_frame['clean_tweet'].apply(
        lambda x : ' '.join([word for word in x.split() 
                             if word not in set(stopwords.words('english')) and len(word) > 3]))
    #Lemmatization
    lemmatizer = WordNetLemmatizer()
    #data_frame['clean_tweet'] = data_frame['clean_tweet'].apply(lambda x : ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))
    wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}
    data_frame['clean_tweet'] = data_frame['clean_tweet'].apply(
        lambda x : ' '.join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in nltk.pos_tag(x.split())]))

    #Code to remove punctuation
    data_frame['clean_tweet'] = data_frame['clean_tweet'].apply(lambda x : re.sub('[%s]' % re.escape(string.punctuation),'',str(x)))
    
    #Stemming
    #ps = PorterStemmer()
    #adwait = data_frame
    #data_frame['clean_tweet'] = data_frame['clean_tweet'].apply(lambda x : ' '.join([ps.stem(word) for word in x.split()]))
    #reset index
    data_frame.reset_index(drop=True, inplace=True)
        
    return data_frame
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/kylielee/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/kylielee/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /Users/kylielee/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#Load EU data
data_path ="https://docs.google.com/spreadsheets/d/e/2PACX-1vSg_vnBwkfqqbrFqPI_IKmGyP2tJ6bz-LKOpRhQAZGXOZ8yIUsp_Cd-z2pgOqj4oA8-Lx9jIHsiZga7/pub?output=csv"
EU_df = pd.read_csv(data_path)
EU_df.shape
# Out:
# (1270, 172)

# %%
#Load NA data
data_path ="https://docs.google.com/spreadsheets/d/e/2PACX-1vR5olDTffDv6ug1khmNLEOcmRwR-RbnydRFEdUtcdBNjwhJODbe49aFIfCrKcq2lO2xEThirDuCBpqj/pub?output=csv"
NA_df = pd.read_csv(data_path)
NA_df.shape
# Out:
# (587, 163)

# %%
#Load Asia data
data_path ="https://docs.google.com/spreadsheets/d/e/2PACX-1vQskpSOD62Y6uXOVKDU5OE7Nb12c__ZPOY68IZUSdeR1cWGrUmhC0qjUVFf_i-BJIKyzn8IxDsIfY5S/pub?output=csv"
AS_df = pd.read_csv(data_path)
AS_df.shape
# Out:
# (421, 161)

# %% [markdown]
# **Europe Data**

# %%
EU_df.info()
EU_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1270 entries, 0 to 1269
# Columns: 172 entries, Unnamed: 0 to user.withheld_in_countries
# dtypes: bool(18), float64(34), int64(11), object(109)
# memory usage: 1.5+ MB
#                  Unnamed: 0  contributors  coordinates  \
# 0  61dfc5708cef26fa7291f8d7           NaN          NaN
# 1  61dfc5708cef26fa7291f8d8           NaN          NaN
# 2  61dfc5708cef26fa7291f8d9           NaN          NaN
# 3  61dfc5708cef26fa7291f8da           NaN          NaN
# 4  61dfc5708cef26fa7291f8db           NaN          NaN
#
#                        created_at entities.hashtags entities.media  \
# 0  Thu Jan 13 03:41:46 +0000 2022                []            NaN
# 1  Thu Jan 13 03:08:25 +0000 2022                []            NaN
# 2  Thu Jan 13 01:40:16 +0000 2022                []            NaN
# 3  Thu Jan 13 00:46:15 +0000 2022                []            NaN
# 4  Thu Jan 13 00:24:42 +0000 2022                []            NaN
#
#   entities.symbols                                      entities.urls  \
# 0               []  [{"url":"https://t.co/cLyuxZTDuZ","expanded_ur...
# 1               []                                                 []
# 2               []                                                 []
# 3               []  [{"url":"https://t.co/lIQg9OS4ZZ","expanded_ur...
# 4               []  [{"url":"https://t.co/fLHDoAb23o","expanded_ur...
#
#                               entities.user_mentions extended_entities.media  \
# 0                                                 []                     NaN
# 1  [{"screen_name":"TheAcademy","name":"The Acade...                     NaN
# 2                                                 []                     NaN
# 3                                                 []                     NaN
# 4                                                 []                     NaN
#
#    ...  user.profile_use_background_image  user.protected  user.screen_name  \
# 0  ...                               True           False   manny_alexandra
# 1  ...                               True           False            Mielzx
# 2  ...                               True           False   cheesesocialist
# 3  ...                              False           False          KingLafs
# 4  ...                               True           False     biggzbando516
#
#    user.statuses_count  user.time_zone user.translator_type  \
# 0                29963             NaN                 none
# 1                45165             NaN              regular
# 2                23722             NaN                 none
# 3               141068             NaN                 none
# 4                 1735             NaN                 none
#
#                   user.url  user.utc_offset  user.verified  \
# 0  https://t.co/Qbrvcx2mvp              NaN          False
# 1                      NaN              NaN          False
# 2                      NaN              NaN          False
# 3  https://t.co/ZMXUBIAjoI              NaN          False
# 4                      NaN              NaN          False
#
#    user.withheld_in_countries
# 0                          []
# 1                          []
# 2                          []
# 3                          []
# 4                          []
#
# [5 rows x 172 columns]

# %%
EU_tweets = EU_df[['text','retweet_count','favorite_count']]

# %%
#Data cleaning
EU_Cleaned = dfCleaning(EU_tweets)

# %%
EU_Cleaned.head(10)
# Out:
#                                                 text  retweet_count  \
# 0      This is a hate crime. https://t.co/cLyuxZTDuZ              0
# 1  @TheAcademy Cate Blanchett, or if she isn’t av...              0
# 2  I haven't been kissed on kiss a ginger day so ...              0
# 3       This is a hate crime https://t.co/lIQg9OS4ZZ              0
# 4  This is a Hate Crime. Yuck https://t.co/fLHDoA...              0
# 5  why are the celebrities ignoring me today this...              0
# 6  @bbceastenders I think story lines like this s...              0
# 7  Black Femicide stats are continuing to rise on...             16
# 8  @RogDangerfield @dhutchings91 lol that word ad...              0
# 9  @metpoliceuk this is a hate crime https://t.co...              0
#
#    favorite_count                                        clean_tweet  \
# 0               0                                         hate crime
# 1               0  cate blanchett available next best kate mckinn...
# 2               0          kiss kiss ginger many year row hate crime
# 3               1                                         hate crime
# 4               0                                    hate crime yuck
# 5               2                  celebrity ignore today hate crime
# 6               0  think story line like air raise awareness culp...
# 7              34  black femicide stats continue rise daily basis...
# 8               0  word admission barmy makes sound like crime ps...
# 9               0                                         hate crime
#
#     Hash words
# 0  No hashtags
# 1  No hashtags
# 2  No hashtags
# 3  No hashtags
# 4  No hashtags
# 5  No hashtags
# 6  No hashtags
# 7  No hashtags
# 8  No hashtags
# 9  No hashtags

# %% [markdown]
# **North America Data**

# %%
NA_tweets = NA_df[['text','retweet_count','favorite_count']]

# %%
NA_Cleaned = dfCleaning(NA_tweets)

# %%
NA_Cleaned.head(10)
# Out:
#                                                 text  retweet_count  \
# 0                @sentinelvayne this is a hate crime              0
# 1  @wedobeguaping no way she committed a hate cri...              0
# 2  Cross Ts And Dot Is....fucking hate this phras...              0
# 3  Suspect in Waukesha Christmas Parade massacre ...              0
# 4  NYC man accused of attacking man for wearing I...              0
# 5  @d_holter2 It's certainly looking that way. Wa...              0
# 6  @BlackKnight10k Hate and Crime….. takes up a l...              0
# 7  Cop Who Killed Ashli Babbitt Was Cleared of Cr...              0
# 8  @ThePlatypusCA @RubieGirlpwr69 @nobleloonlodge...              1
# 9  I can't believe in WA State you can admit to b...              0
#
#    favorite_count                                        clean_tweet  \
# 0               0                                         hate crime
# 1               1                                  commit hate crime
# 2               1  cross isfucking hate phrase every actioncrime ...
# 3               0  suspect waukesha christmas parade massacre fac...
# 4               0  accuse attack wear israel defense force hoodie...
# 5               0  certainly look way watch trail like watch trai...
# 6               0                               hate crime take time
# 7               0  kill ashli babbitt clear criminal wrongdoing w...
# 8               4              prof princess sound like hate crime t
# 9               1  cant believe state admit party hate crime murd...
#
#     Hash words
# 0  No hashtags
# 1  No hashtags
# 2  No hashtags
# 3  No hashtags
# 4  No hashtags
# 5  No hashtags
# 6  No hashtags
# 7  No hashtags
# 8  No hashtags
# 9  No hashtags

# %% [markdown]
# **Asia Data**

# %%
AS_tweets = AS_df[['text','retweet_count','favorite_count']]

# %%
AS_Cleaned = dfCleaning(AS_tweets)

# %%
AS_Cleaned.head()
# Out:
#                                                 text  retweet_count  \
# 0  @therealnaomib Don't hate the criminal.Hate th...              0
# 1  @vijaythottathil He should be charged under UA...              0
# 2  Criminal crime minister\nWe hate\n#ForeignFund...              0
# 3  We should hate both crime and criminals. The o...              5
# 4  @mr_mayank May be now he would be charged by t...              0
#
#    favorite_count                                        clean_tweet  \
# 0               0                            hate criminalhate crime
# 1               2  charge uapa hate speech muslim genocide congre...
# 2               0  criminal crime minister hate foreignfundedcrim...
# 3               5     hate crime criminals make law talent killed he
# 4               0  would charge government hate speech previous c...
#
#                     Hash words
# 0                  No hashtags
# 1                  No hashtags
# 2  #foreignfundedcrimeminister
# 3                  No hashtags
# 4                  No hashtags

# %% [markdown]
# **EDA**

# %% [markdown]
# *Tweet Count*

# %%
#count the total tweets of each dataframe
dataframes = {'EU': EU_Cleaned, 'NA': NA_Cleaned, 'AS': AS_Cleaned}
df_region = pd.DataFrame([(i, df.shape[0]) for i, df in dataframes.items()],
                            columns=['df','count_rows'])

#tweets for each region_plot
fig, ax = plt.subplots(figsize=(12,8))

labels = df_region['df']
colors = sns.color_palette("Greens")

ax.pie(df_region['count_rows'], labels=labels, colors=colors, autopct='%.1f%%',
       wedgeprops={'linewidth': 2.0, 'edgecolor': 'white'},
       textprops={'size': 'x-large'})
ax.set_title('Tweets for each region', fontsize=12)

plt.show()

# %% [markdown]
# *Retweet Count*

# %%
#retweet_count plots
fig, axs = plt.subplots(1,3, figsize=(18,16))

ax1=sns.countplot(x='retweet_count', data=EU_Cleaned, ax=axs[0])
ax1.set(title='Europe')
ax1.set_xlim([0, 25])

ax2=sns.countplot(x='retweet_count', data=NA_Cleaned, ax=axs[1])
ax2.set(title='North America')
ax2.set_xlim([0, 25])

ax3=sns.countplot(x='retweet_count', data=AS_Cleaned, ax=axs[2])
ax3.set(title='Asia')
ax3.set_xlim([0, 25])

plt.show()

# %% [markdown]
# *Favorite Count*

# %%
#favorite_count plots
fig, axs = plt.subplots(1,3, figsize=(18,16))

ax1=sns.countplot(x='favorite_count', data=EU_Cleaned, ax=axs[0])
ax1.set(title='Europe')
ax1.set_xlim([0, 25])

ax2=sns.countplot(x='favorite_count', data=NA_Cleaned, ax=axs[1])
ax2.set(title='North America')
ax2.set_xlim([0, 25])

ax3=sns.countplot(x='favorite_count', data=AS_Cleaned, ax=axs[2])
ax3.set(title='Asia')
ax3.set_xlim([0, 25])

plt.show()

# %% [markdown]
# *Most Common Words*

# %% [markdown]
# *EU*

# %%
#Most common words
EU_Cleaned['temp_list'] = EU_Cleaned['clean_tweet'].apply(lambda x:str(x).split())
top = Counter([item for sublist in EU_Cleaned['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_5ed4a_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_5ed4a_row1_col1 {
#   background-color: #430780;
#   color: #f1f1f1;
# }
# #T_5ed4a_row2_col1, #T_5ed4a_row3_col1 {
#   background-color: #f7f6fa;
#   color: #000000;
# }
# #T_5ed4a_row4_col1, #T_5ed4a_row5_col1 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_5ed4a_row6_col1 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# #T_5ed4a_row7_col1 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_5ed4a_row8_col1, #T_5ed4a_row9_col1, #T_5ed4a_row10_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_5ed4a_row11_col1, #T_5ed4a_row12_col1, #T_5ed4a_row13_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_5ed4a_row14_col1, #T_5ed4a_row15_col1, #T_5ed4a_row16_col1, #T_5ed4a_row17_col1, #T_5ed4a_row18_col1, #T_5ed4a_row19_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_5ed4a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ed4a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ed4a_row0_col0" class="data row0 col0" >hate</td>
#       <td id="T_5ed4a_row0_col1" class="data row0 col1" >839</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5ed4a_row1_col0" class="data row1 col0" >crime</td>
#       <td id="T_5ed4a_row1_col1" class="data row1 col1" >817</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5ed4a_row2_col0" class="data row2 col0" >statue</td>
#       <td id="T_5ed4a_row2_col1" class="data row2 col1" >69</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5ed4a_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_5ed4a_row3_col1" class="data row3 col1" >68</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5ed4a_row4_col0" class="data row4 col0" >people</td>
#       <td id="T_5ed4a_row4_col1" class="data row4 col1" >65</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5ed4a_row5_col0" class="data row5 col0" >make</td>
#       <td id="T_5ed4a_row5_col1" class="data row5 col1" >63</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5ed4a_row6_col0" class="data row6 col0" >need</td>
#       <td id="T_5ed4a_row6_col1" class="data row6 col1" >57</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5ed4a_row7_col0" class="data row7 col0" >would</td>
#       <td id="T_5ed4a_row7_col1" class="data row7 col1" >54</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5ed4a_row8_col0" class="data row8 col0" >report</td>
#       <td id="T_5ed4a_row8_col1" class="data row8 col1" >45</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5ed4a_row9_col0" class="data row9 col0" >think</td>
#       <td id="T_5ed4a_row9_col1" class="data row9 col1" >43</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5ed4a_row10_col0" class="data row10 col0" >attack</td>
#       <td id="T_5ed4a_row10_col1" class="data row10 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5ed4a_row11_col0" class="data row11 col0" >year</td>
#       <td id="T_5ed4a_row11_col1" class="data row11 col1" >40</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5ed4a_row12_col0" class="data row12 col0" >police</td>
#       <td id="T_5ed4a_row12_col1" class="data row12 col1" >39</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5ed4a_row13_col0" class="data row13 col0" >say</td>
#       <td id="T_5ed4a_row13_col1" class="data row13 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5ed4a_row14_col0" class="data row14 col0" >word</td>
#       <td id="T_5ed4a_row14_col1" class="data row14 col1" >32</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5ed4a_row15_col0" class="data row15 col0" >first</td>
#       <td id="T_5ed4a_row15_col1" class="data row15 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5ed4a_row16_col0" class="data row16 col0" >change</td>
#       <td id="T_5ed4a_row16_col1" class="data row16 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5ed4a_row17_col0" class="data row17 col0" >misogyny</td>
#       <td id="T_5ed4a_row17_col1" class="data row17 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5ed4a_row18_col0" class="data row18 col0" >criminal</td>
#       <td id="T_5ed4a_row18_col1" class="data row18 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_5ed4a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5ed4a_row19_col0" class="data row19 col0" >thats</td>
#       <td id="T_5ed4a_row19_col1" class="data row19 col1" >28</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Bar plot for most common words
plt.figure(figsize=(12,8))
sns.barplot(y='Common_words', x='count', data=temp)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Common_words'>

# %% [markdown]
# *NA*

# %%
#Most common words
NA_Cleaned['temp_list'] = NA_Cleaned['clean_tweet'].apply(lambda x:str(x).split())
top = Counter([item for sublist in NA_Cleaned['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_99693_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_99693_row1_col1 {
#   background-color: #4c1788;
#   color: #f1f1f1;
# }
# #T_99693_row2_col1 {
#   background-color: #f0eef5;
#   color: #000000;
# }
# #T_99693_row3_col1 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_99693_row4_col1 {
#   background-color: #f4f3f8;
#   color: #000000;
# }
# #T_99693_row5_col1 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_99693_row6_col1 {
#   background-color: #f7f6fa;
#   color: #000000;
# }
# #T_99693_row7_col1 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_99693_row8_col1, #T_99693_row9_col1, #T_99693_row10_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_99693_row11_col1, #T_99693_row12_col1, #T_99693_row13_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_99693_row14_col1, #T_99693_row15_col1, #T_99693_row16_col1, #T_99693_row17_col1, #T_99693_row18_col1, #T_99693_row19_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_99693_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99693_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99693_row0_col0" class="data row0 col0" >hate</td>
#       <td id="T_99693_row0_col1" class="data row0 col1" >421</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99693_row1_col0" class="data row1 col0" >crime</td>
#       <td id="T_99693_row1_col1" class="data row1 col1" >391</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99693_row2_col0" class="data row2 col0" >black</td>
#       <td id="T_99693_row2_col1" class="data row2 col1" >67</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99693_row3_col0" class="data row3 col0" >charge</td>
#       <td id="T_99693_row3_col1" class="data row3 col1" >63</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99693_row4_col0" class="data row4 col0" >attack</td>
#       <td id="T_99693_row4_col1" class="data row4 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_99693_row5_col0" class="data row5 col0" >white</td>
#       <td id="T_99693_row5_col1" class="data row5 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_99693_row6_col0" class="data row6 col0" >asian</td>
#       <td id="T_99693_row6_col1" class="data row6 col1" >39</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_99693_row7_col0" class="data row7 col0" >like</td>
#       <td id="T_99693_row7_col1" class="data row7 col1" >33</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_99693_row8_col0" class="data row8 col0" >people</td>
#       <td id="T_99693_row8_col1" class="data row8 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_99693_row9_col0" class="data row9 col0" >murder</td>
#       <td id="T_99693_row9_col1" class="data row9 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_99693_row10_col0" class="data row10 col0" >federal</td>
#       <td id="T_99693_row10_col1" class="data row10 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_99693_row11_col0" class="data row11 col0" >amp</td>
#       <td id="T_99693_row11_col1" class="data row11 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_99693_row12_col0" class="data row12 col0" >call</td>
#       <td id="T_99693_row12_col1" class="data row12 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_99693_row13_col0" class="data row13 col0" >dy</td>
#       <td id="T_99693_row13_col1" class="data row13 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_99693_row14_col0" class="data row14 col0" >know</td>
#       <td id="T_99693_row14_col1" class="data row14 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_99693_row15_col0" class="data row15 col0" >chinese</td>
#       <td id="T_99693_row15_col1" class="data row15 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_99693_row16_col0" class="data row16 col0" >kill</td>
#       <td id="T_99693_row16_col1" class="data row16 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_99693_row17_col0" class="data row17 col0" >commit</td>
#       <td id="T_99693_row17_col1" class="data row17 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_99693_row18_col0" class="data row18 col0" >eight</td>
#       <td id="T_99693_row18_col1" class="data row18 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_99693_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_99693_row19_col0" class="data row19 col0" >month</td>
#       <td id="T_99693_row19_col1" class="data row19 col1" >19</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Bar plot for most common words
plt.figure(figsize=(12,8))
sns.barplot(y='Common_words', x='count', data=temp)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Common_words'>

# %% [markdown]
# *AS*

# %%
#Most common words
AS_Cleaned['temp_list'] = AS_Cleaned['clean_tweet'].apply(lambda x:str(x).split())
top = Counter([item for sublist in AS_Cleaned['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_aed8f_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_aed8f_row1_col1 {
#   background-color: #4f1f8b;
#   color: #f1f1f1;
# }
# #T_aed8f_row2_col1 {
#   background-color: #f3f2f8;
#   color: #000000;
# }
# #T_aed8f_row3_col1, #T_aed8f_row4_col1 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_aed8f_row5_col1, #T_aed8f_row6_col1 {
#   background-color: #f8f7fa;
#   color: #000000;
# }
# #T_aed8f_row7_col1 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_aed8f_row8_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_aed8f_row9_col1, #T_aed8f_row10_col1, #T_aed8f_row11_col1, #T_aed8f_row12_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_aed8f_row13_col1, #T_aed8f_row14_col1, #T_aed8f_row15_col1, #T_aed8f_row16_col1, #T_aed8f_row17_col1, #T_aed8f_row18_col1, #T_aed8f_row19_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_aed8f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aed8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aed8f_row0_col0" class="data row0 col0" >hate</td>
#       <td id="T_aed8f_row0_col1" class="data row0 col1" >303</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aed8f_row1_col0" class="data row1 col0" >crime</td>
#       <td id="T_aed8f_row1_col1" class="data row1 col1" >274</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aed8f_row2_col0" class="data row2 col0" >muslim</td>
#       <td id="T_aed8f_row2_col1" class="data row2 col1" >37</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aed8f_row3_col0" class="data row3 col0" >speech</td>
#       <td id="T_aed8f_row3_col1" class="data row3 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aed8f_row4_col0" class="data row4 col0" >people</td>
#       <td id="T_aed8f_row4_col1" class="data row4 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aed8f_row5_col0" class="data row5 col0" >amp</td>
#       <td id="T_aed8f_row5_col1" class="data row5 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aed8f_row6_col0" class="data row6 col0" >online</td>
#       <td id="T_aed8f_row6_col1" class="data row6 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aed8f_row7_col0" class="data row7 col0" >like</td>
#       <td id="T_aed8f_row7_col1" class="data row7 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aed8f_row8_col0" class="data row8 col0" >charge</td>
#       <td id="T_aed8f_row8_col1" class="data row8 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aed8f_row9_col0" class="data row9 col0" >say</td>
#       <td id="T_aed8f_row9_col1" class="data row9 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_aed8f_row10_col0" class="data row10 col0" >women</td>
#       <td id="T_aed8f_row10_col1" class="data row10 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_aed8f_row11_col0" class="data row11 col0" >attack</td>
#       <td id="T_aed8f_row11_col1" class="data row11 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_aed8f_row12_col0" class="data row12 col0" >woman</td>
#       <td id="T_aed8f_row12_col1" class="data row12 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_aed8f_row13_col0" class="data row13 col0" >york</td>
#       <td id="T_aed8f_row13_col1" class="data row13 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_aed8f_row14_col0" class="data row14 col0" >chinese</td>
#       <td id="T_aed8f_row14_col1" class="data row14 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_aed8f_row15_col0" class="data row15 col0" >sikh</td>
#       <td id="T_aed8f_row15_col1" class="data row15 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_aed8f_row16_col0" class="data row16 col0" >national</td>
#       <td id="T_aed8f_row16_col1" class="data row16 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_aed8f_row17_col0" class="data row17 col0" >protest</td>
#       <td id="T_aed8f_row17_col1" class="data row17 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_aed8f_row18_col0" class="data row18 col0" >hindu</td>
#       <td id="T_aed8f_row18_col1" class="data row18 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_aed8f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_aed8f_row19_col0" class="data row19 col0" >know</td>
#       <td id="T_aed8f_row19_col1" class="data row19 col1" >13</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Bar plot for most common words
plt.figure(figsize=(12,8))
sns.barplot(y='Common_words', x='count', data=temp)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Common_words'>

# %% [markdown]
# **Wordclouds**

# %%
def my_tf_color_func(dictionary):
  def my_tf_color_func_inner(word, **kwargs):
    return "hsl(%d, 80%%, 50%%)" % (360 * dictionary[word])
  return my_tf_color_func_inner

# %% [markdown]
# *EU*

# %%
normal_words = ' '.join([word for word in EU_Cleaned['clean_tweet']])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "white").generate(normal_words)
print('Normal words')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='viridis')
plt.axis('off')
# Out:
# Normal words
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# *NA*

# %%
normal_words = ' '.join([word for word in NA_Cleaned['clean_tweet']])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "white").generate(normal_words)
print('Normal words')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='viridis')
plt.axis('off')
# Out:
# Normal words
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# *AS*

# %%
normal_words = ' '.join([word for word in AS_Cleaned['clean_tweet']])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "white").generate(normal_words)
print('Normal words')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='viridis')
plt.axis('off')
# Out:
# Normal words
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# **Vader Sentiment Analysis**
# - polarity
# - subjectivity
# - neg, neu, pos scores
# - compound
# -sentiment

# %% [markdown]
# *Europe*

# %%
#Europe
sia = SentimentIntensityAnalyzer()
EU_Cleaned[['polarity', 'subjectivity']] = EU_Cleaned['clean_tweet'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, s in enumerate(EU_Cleaned['text']):
  ps = sia.polarity_scores(s)
  EU_Cleaned.loc[index,['neg']] = ps['neg']
  EU_Cleaned.loc[index,['neu']] = ps['neu']
  EU_Cleaned.loc[index,['pos']] = ps['pos']
  EU_Cleaned.loc[index,['compound']] = ps['compound']
  if ps['neg'] > ps['pos']:
    EU_Cleaned.loc[index,['sentiment']] = 'negative'
  elif ps['pos'] > ps['neg']:
    EU_Cleaned.loc[index,['sentiment']] = 'positive'
  else:
    EU_Cleaned.loc[index,['sentiment']] = 'neutral'
   
EU_Cleaned.head(10)
# Out:
#                                                 text  retweet_count  \
# 0      This is a hate crime. https://t.co/cLyuxZTDuZ              0
# 1  @TheAcademy Cate Blanchett, or if she isn’t av...              0
# 2  I haven't been kissed on kiss a ginger day so ...              0
# 3       This is a hate crime https://t.co/lIQg9OS4ZZ              0
# 4  This is a Hate Crime. Yuck https://t.co/fLHDoA...              0
# 5  why are the celebrities ignoring me today this...              0
# 6  @bbceastenders I think story lines like this s...              0
# 7  Black Femicide stats are continuing to rise on...             16
# 8  @RogDangerfield @dhutchings91 lol that word ad...              0
# 9  @metpoliceuk this is a hate crime https://t.co...              0
#
#    favorite_count                                        clean_tweet  \
# 0               0                                         hate crime
# 1               0  cate blanchett available next best kate mckinn...
# 2               0          kiss kiss ginger many year row hate crime
# 3               1                                         hate crime
# 4               0                                    hate crime yuck
# 5               2                  celebrity ignore today hate crime
# 6               0  think story line like air raise awareness culp...
# 7              34  black femicide stats continue rise daily basis...
# 8               0  word admission barmy makes sound like crime ps...
# 9               0                                         hate crime
#
#     Hash words                                          temp_list  polarity  \
# 0  No hashtags                                      [hate, crime] -0.800000
# 1  No hashtags  [cate, blanchett, available, next, best, kate,...  0.150000
# 2  No hashtags  [kiss, kiss, ginger, many, year, row, hate, cr... -0.150000
# 3  No hashtags                                      [hate, crime] -0.800000
# 4  No hashtags                                [hate, crime, yuck] -0.800000
# 5  No hashtags            [celebrity, ignore, today, hate, crime] -0.800000
# 6  No hashtags  [think, story, line, like, air, raise, awarene...  0.000000
# 7  No hashtags  [black, femicide, stats, continue, rise, daily... -0.055556
# 8  No hashtags  [word, admission, barmy, makes, sound, like, c...  0.400000
# 9  No hashtags                                      [hate, crime] -0.800000
#
#    subjectivity    neg    neu    pos  compound sentiment
# 0      0.900000  0.706  0.294  0.000   -0.8020  negative
# 1      0.400000  0.245  0.612  0.143   -0.4588  negative
# 2      0.700000  0.388  0.496  0.116   -0.7639  negative
# 3      0.900000  0.706  0.294  0.000   -0.8020  negative
# 4      0.900000  0.643  0.357  0.000   -0.8020  negative
# 5      0.900000  0.553  0.447  0.000   -0.8720  negative
# 6      0.000000  0.000  0.916  0.084    0.1901  positive
# 7      0.144444  0.000  1.000  0.000    0.0000   neutral
# 8      0.400000  0.141  0.645  0.214    0.2023  positive
# 9      0.900000  0.643  0.357  0.000   -0.8020  negative

# %%
#EU Histograms of polarity and subjectivity
n_bins = 50
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18,7))
ax1.hist(EU_Cleaned["polarity"], bins = n_bins)
ax1.set_title('EU Polarity Scores')
ax2.hist(EU_Cleaned["subjectivity"], bins = n_bins)
ax2.set_title('EU Subjectivity Scores')
plt.show()

# %%
#EU Counterplot of sentiment
sns.set(rc={'figure.figsize':(10,7)})
ax = sns.countplot(x="sentiment", data=EU_Cleaned)
ax.set(xlabel='Europe Sentiment Result')
# Out:
# [Text(0.5, 0, 'Europe Sentiment Result')]

# %% [markdown]
# *North Amercia*

# %%
#North America
sia = SentimentIntensityAnalyzer()
NA_Cleaned[['polarity', 'subjectivity']] = NA_Cleaned['clean_tweet'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, s in enumerate(NA_Cleaned['text']):
  ps = sia.polarity_scores(s)
  NA_Cleaned.loc[index,['neg']] = ps['neg']
  NA_Cleaned.loc[index,['neu']] = ps['neu']
  NA_Cleaned.loc[index,['pos']] = ps['pos']
  NA_Cleaned.loc[index,['compound']] = ps['compound']
  if ps['neg'] > ps['pos']:
    NA_Cleaned.loc[index,['sentiment']] = 'negative'
  elif ps['pos'] > ps['neg']:
    NA_Cleaned.loc[index,['sentiment']] = 'positive'
  else:
    NA_Cleaned.loc[index,['sentiment']] = 'neutral'
   
NA_Cleaned.head()
# Out:
#                                                 text  retweet_count  \
# 0                @sentinelvayne this is a hate crime              0
# 1  @wedobeguaping no way she committed a hate cri...              0
# 2  Cross Ts And Dot Is....fucking hate this phras...              0
# 3  Suspect in Waukesha Christmas Parade massacre ...              0
# 4  NYC man accused of attacking man for wearing I...              0
#
#    favorite_count                                        clean_tweet  \
# 0               0                                         hate crime
# 1               1                                  commit hate crime
# 2               1  cross isfucking hate phrase every actioncrime ...
# 3               0  suspect waukesha christmas parade massacre fac...
# 4               0  accuse attack wear israel defense force hoodie...
#
#     Hash words                                          temp_list  polarity  \
# 0  No hashtags                                      [hate, crime]    -0.800
# 1  No hashtags                              [commit, hate, crime]    -0.800
# 2  No hashtags  [cross, isfucking, hate, phrase, every, action...    -0.300
# 3  No hashtags  [suspect, waukesha, christmas, parade, massacr...    -0.525
# 4  No hashtags  [accuse, attack, wear, israel, defense, force,...    -0.800
#
#    subjectivity    neg    neu    pos  compound sentiment
# 0      0.900000  0.706  0.294  0.000   -0.8020  negative
# 1      0.900000  0.570  0.303  0.127   -0.8074  negative
# 2      0.437500  0.147  0.754  0.099   -0.2960  negative
# 3      0.566667  0.511  0.489  0.000   -0.9118  negative
# 4      0.900000  0.562  0.390  0.049   -0.9413  negative

# %%
#NA Histograms of polarity and subjectivity
n_bins = 50
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18,7))
ax1.hist(NA_Cleaned["polarity"], bins = n_bins)
ax1.set_title('NA Polarity Scores')
ax2.hist(NA_Cleaned["subjectivity"], bins = n_bins)
ax2.set_title('NA Subjectivity Scores')
plt.show()

# %%
#NA Counterplot of sentiment
sns.set(rc={'figure.figsize':(10,7)})
ax = sns.countplot(x="sentiment", data=NA_Cleaned)
ax.set(xlabel='North America Sentiment Result')
# Out:
# [Text(0.5, 0, 'North America Sentiment Result')]

# %% [markdown]
# *Asia*

# %%
#Asia
sia = SentimentIntensityAnalyzer()
AS_Cleaned[['polarity', 'subjectivity']] = AS_Cleaned['clean_tweet'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, s in enumerate(AS_Cleaned['text']):
  ps = sia.polarity_scores(s)
  AS_Cleaned.loc[index,['neg']] = ps['neg']
  AS_Cleaned.loc[index,['neu']] = ps['neu']
  AS_Cleaned.loc[index,['pos']] = ps['pos']
  AS_Cleaned.loc[index,['compound']] = ps['compound']
  if ps['neg'] > ps['pos']:
    AS_Cleaned.loc[index,['sentiment']] = 'negative'
  elif ps['pos'] > ps['neg']:
    AS_Cleaned.loc[index,['sentiment']] = 'positive'
  else:
    AS_Cleaned.loc[index,['sentiment']] = 'neutral'
   
AS_Cleaned.head()
# Out:
#                                                 text  retweet_count  \
# 0  @therealnaomib Don't hate the criminal.Hate th...              0
# 1  @vijaythottathil He should be charged under UA...              0
# 2  Criminal crime minister\nWe hate\n#ForeignFund...              0
# 3  We should hate both crime and criminals. The o...              5
# 4  @mr_mayank May be now he would be charged by t...              0
#
#    favorite_count                                        clean_tweet  \
# 0               0                            hate criminalhate crime
# 1               2  charge uapa hate speech muslim genocide congre...
# 2               0  criminal crime minister hate foreignfundedcrim...
# 3               5     hate crime criminals make law talent killed he
# 4               0  would charge government hate speech previous c...
#
#                     Hash words  \
# 0                  No hashtags
# 1                  No hashtags
# 2  #foreignfundedcrimeminister
# 3                  No hashtags
# 4                  No hashtags
#
#                                            temp_list  polarity  subjectivity  \
# 0                        [hate, criminalhate, crime] -0.800000      0.900000
# 1  [charge, uapa, hate, speech, muslim, genocide,... -0.800000      0.900000
# 2  [criminal, crime, minister, hate, foreignfunde... -0.600000      0.725000
# 3  [hate, crime, criminals, make, law, talent, ki... -0.500000      0.450000
# 4  [would, charge, government, hate, speech, prev... -0.483333      0.533333
#
#      neg    neu    pos  compound sentiment
# 0  0.304  0.435  0.261   -0.1285  negative
# 1  0.244  0.756  0.000   -0.6705  negative
# 2  0.779  0.221  0.000   -0.8910  negative
# 3  0.423  0.495  0.082   -0.9246  negative
# 4  0.224  0.776  0.000   -0.6705  negative

# %%
#AS Histograms of polarity and subjectivity
n_bins = 50
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18,7))
ax1.hist(AS_Cleaned["polarity"], bins = n_bins)
ax1.set_title('AS Polarity Scores')
ax2.hist(AS_Cleaned["subjectivity"], bins = n_bins)
ax2.set_title('AS Subjectivity Scores')
plt.show()

# %%
#AS Counterplot of sentiment
sns.set(rc={'figure.figsize':(10,7)})
ax = sns.countplot(x="sentiment", data=AS_Cleaned)
ax.set(xlabel='Asia Sentiment Result')
# Out:
# [Text(0.5, 0, 'Asia Sentiment Result')]
