# %%
EU_Cleaned.head()
# Out:
#                                                 text  ...   Hash words
# 0      This is a hate crime. https://t.co/cLyuxZTDuZ  ...  No hashtags
# 1  @TheAcademy Cate Blanchett, or if she isn’t av...  ...  No hashtags
# 2  I haven't been kissed on kiss a ginger day so ...  ...  No hashtags
# 3       This is a hate crime https://t.co/lIQg9OS4ZZ  ...  No hashtags
# 4  This is a Hate Crime. Yuck https://t.co/fLHDoA...  ...  No hashtags
#
# [5 rows x 5 columns]

# %%
NA_Cleaned.head()
# Out:
#                                                 text  ...   Hash words
# 0                @sentinelvayne this is a hate crime  ...  No hashtags
# 1  @wedobeguaping no way she committed a hate cri...  ...  No hashtags
# 2  Cross Ts And Dot Is....fucking hate this phras...  ...  No hashtags
# 3  Suspect in Waukesha Christmas Parade massacre ...  ...  No hashtags
# 4  NYC man accused of attacking man for wearing I...  ...  No hashtags
#
# [5 rows x 5 columns]

# %%
AS_Cleaned.head()
# Out:
#                                                 text  ...                   Hash words
# 0  @therealnaomib Don't hate the criminal.Hate th...  ...                  No hashtags
# 1  @vijaythottathil He should be charged under UA...  ...                  No hashtags
# 2  Criminal crime minister\nWe hate\n#ForeignFund...  ...  #ForeignFundedCrimeMinister
# 3  We should hate both crime and criminals. The o...  ...                  No hashtags
# 4  @mr_mayank May be now he would be charged by t...  ...                  No hashtags
#
# [5 rows x 5 columns]

# %% [markdown]
# EU Hashtags

# %%
hashtags = ' '.join([word for word in EU_Cleaned['Hash words'].unique()])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "white").generate(hashtags)
print('hashtags')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='viridis')
plt.axis('off')
# Out:
# hashtags
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# NA Hashtags

# %%
hashtags = ' '.join([word for word in NA_Cleaned['Hash words'].unique()])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "white").generate(hashtags)
print('hashtags')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='viridis')
plt.axis('off')
# Out:
# hashtags
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# AS Hashtags

# %%
hashtags = ' '.join([word for word in AS_Cleaned['Hash words'].unique()])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "white").generate(hashtags)
print('hashtags')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='viridis')
plt.axis('off')
# Out:
# hashtags
# (-0.5, 799.5, 499.5, -0.5)
